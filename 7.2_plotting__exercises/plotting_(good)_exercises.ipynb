# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good) Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %%
import matplotlib.pyplot as plt
import numpy as np

#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1, color='g', alpha=.125)
axes[0, 0].set_xlabel('Angle (radians)')
axes[0, 0].text(0, 0, 'I am [0, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, cos_x, -2, color='r', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('Cosine Value')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='lower right', frameon=False)
axes[0, 1].text(0, 0, 'I am [0, 1]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
axes[1, 0].fill_between(x, fun1_x, 0, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend()
axes[1, 0].text(0, 0, 'I am [1, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, 10, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].legend()
axes[1, 1].text(0, 0, 'I am [1, 1]!', fontsize=30,
                horizontalalignment='center')

# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

# plt.tight_layout()
plt.show(block=False)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# <>:19: SyntaxWarning: invalid escape sequence '\c'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:49: SyntaxWarning: invalid escape sequence '\s'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# <>:19: SyntaxWarning: invalid escape sequence '\c'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\c'
# <>:39: SyntaxWarning: invalid escape sequence '\c'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:49: SyntaxWarning: invalid escape sequence '\s'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:16: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:18: SyntaxWarning: invalid escape sequence '\c'
#   linestyle=':', label='$\cos^2 x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:19: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:27: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:29: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:37: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:39: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].set_title('$e^{-x}\cos 5x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:43: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:43: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:43: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:43: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:49: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/1903282943.py:50: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].set_title('$e^{-x}\sin 2x$')

# %% [markdown]
# ## Answer

# %%
import numpy as np
import matplotlib.pyplot as plt

#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row', sharex='col')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1, color='r', alpha=.125)
axes[0, 0].set_xlim(-np.pi, np.pi)
axes[0, 0].legend(loc='upper right')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -2, color='g', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
#axes[0, 1].set_ylabel('Cosine Value')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].set_xlim(-np.pi, np.pi) # added once to apply for subplot 2 and 4
axes[0, 1].set_title('$\sin x$ & $\sin^2x$')
axes[0, 1].legend(loc='upper right', frameon=True)


#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$\sin 2x$')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125)
# the '-25' is the secondary y-boundary (aka fill the gap between the curve and y=-25)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend(loc = 'upper right')
#axes[1, 0].text(0, 0, 'I am [1, 0]!', fontsize=30,
#                horizontalalignment='center')

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, -25, color='y', alpha=.125)
axes[1, 1].set_xlabel('Angle (radians)')
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 1].legend()
#axes[1, 1].text(0, 0, 'I am [1, 1]!', fontsize=30,
#                horizontalalignment='center')

# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

plt.tight_layout()
plt.savefig('plotting_(good)_exercise_2.jpg', dpi = 200) # plt.savefig() must be BEFORE plt.show()
plt.show(block=False)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# <>:19: SyntaxWarning: invalid escape sequence '\c'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\s'
# <>:40: SyntaxWarning: invalid escape sequence '\c'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# <>:51: SyntaxWarning: invalid escape sequence '\s'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:16: SyntaxWarning: invalid escape sequence '\c'
# <>:18: SyntaxWarning: invalid escape sequence '\c'
# <>:19: SyntaxWarning: invalid escape sequence '\c'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\s'
# <>:40: SyntaxWarning: invalid escape sequence '\c'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:44: SyntaxWarning: invalid escape sequence '\p'
# <>:50: SyntaxWarning: invalid escape sequence '\s'
# <>:51: SyntaxWarning: invalid escape sequence '\s'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# <>:55: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:16: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:18: SyntaxWarning: invalid escape sequence '\c'
#   linestyle=':', label='$\cos^2 x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:19: SyntaxWarning: invalid escape sequence '\c'
#   axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:26: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:28: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:32: SyntaxWarning: invalid escape sequence '\s'
#   axes[0, 1].set_title('$\sin x$ & $\sin^2x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:37: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 0].plot(x, fun1_x, color='b', label='$\sin 2x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:40: SyntaxWarning: invalid escape sequence '\c'
#   axes[1, 0].set_title('$e^{-x}\cos 5x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:44: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:50: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].plot(x, fun2_x, color='y', label='$\sin 2x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:51: SyntaxWarning: invalid escape sequence '\s'
#   axes[1, 1].set_title('$e^{-x}\sin 2x$')
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:55: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:55: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:55: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# /var/folders/t9/g1m0p2211c3czq71k1d6c26c0000gn/T/ipykernel_1561/3765406233.py:55: SyntaxWarning: invalid escape sequence '\p'
#   axes[1, 1].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
