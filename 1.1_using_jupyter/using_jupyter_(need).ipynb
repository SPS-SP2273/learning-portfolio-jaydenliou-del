# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Getting ready

# %% [markdown]
# # 2 Getting started with Jupyter

# %% [markdown]
# ## 2.1 It is all about running cells

# %% [markdown]
# ## 2.2 A traditional start

# %% [markdown]
# # 3 All about Markdown

# %% [markdown]
# ## 3.1 Rendering Markdown cells

# %% [markdown]
# ## 3.2 Some basic syntax

# %% [markdown]
# **BOLD** # bold uses **  ** or __ (double underscore)

# %% [markdown]
# *ITALIC* # italic uses * * or _ (single underscore)

# %% [markdown]
# ***ALL BOLD AND ITALIC*** # all bold and italic uses ***  ***

# %% [markdown]
# ## 3.3 Headings

# %% [markdown]
# # Largest Heading uses 1x hashtag

# %% [markdown]
# ## Second Largest Heading uses 2x hashtag

# %% [markdown]
# ### Third Largest Heading uses 3x hashtag

# %% [markdown]
# #### The Smallest Heading uses 4x hashtag

# %% [markdown]
# ## 3.4 Displaying Code

# %% [markdown]
# ``` python
# print('Hello World!')
# ```
# #use triple backticks ``` at the start and end to display a block of code

# %% [markdown]
# Use `print('Hello World!')` to display text # use ` at start and end to display code inside a text

# %% [markdown]
# ## 3.5 Links

# %% [markdown]
# To underline url text, use < u > at the start and end of the text

# %% [markdown]
# [<u>SP2273 Website<u>](https://sps.nus.edu.sg/sp2273)

# %% [markdown]
# ## 3.6 Images

# %% [markdown]
# Syntax for images is ! [] ( URL )

# %% [markdown]
# ![](https://nus.edu.sg/images/default-source/base/logo.png)

# %% [markdown]
# ## 3.7 Tables

# %% [markdown]
# | Column 1 | Column 2 |
# | :--: | :--: |
# | a1 | b1 |

# %% [markdown]
# | Header 1 (Left)| Header 2 | Header 3 (Right) |
# | :--- | :---: | ---: |
# | 1 | 2 | 3|
# |a1|a2|a3|

# %% [markdown]
# ## 3.8 Lists

# %% [markdown]
# 1. Master Yoda
# 2. Luke skywalker
# 3. Anakin skywalker

# %% [markdown]
# - master yoda
# - master luke
# - master anakin

# %% [markdown]
# ## 3.9 Equations

# %% [markdown]
# $$
# x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$

# %%
# \sin
# \cos
# \tan
# \log
# \log
# \exp

# %% [markdown]
# $\lim_{x \to 0}$

# %% [markdown]
# $ a \ne b $

# %% [markdown]
# $$ \mu = \dfrac{1}{n} \sum_{i=1}^{n} x_{i} $$

# %% [markdown]
# ## Footnotes
