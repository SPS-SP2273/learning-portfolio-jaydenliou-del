# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need), Exercises</span></div>

# %% [markdown]
# ## 1 Quadratic Equations

# %% [markdown]
# ### Introduction

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Polynomialdeg2.svg/300px-Polynomialdeg2.svg.png)

# %% [markdown]
# (_Image from the <u>[Wikipedia page on Quadratic equations](https://en.wikipedia.org/wiki/Quadratic_equation)<u>_)

# %% [markdown]
# The general form of a quadratic equation is:

# %% [markdown]
# $$ax^2 + bx + c = 0$$

# %% [markdown]
# ### Solutions

# %% [markdown]
# Provied $a \ne 0$, we can use an elementary algebraic method called [<u>completing the square</u>](https://en.wikipedia.org/wiki/Completing_the_square) to show that a quadratic equation has the following solution:

# %% [markdown]
# $$
# x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# ### Discriminant

# %% [markdown]
# The quantity $\Delta$ = $b^2 - 4ac$ is called the __discriminant__ of the equation and decides the nature of its solutions. The table below shows the various possibilities.

# %% [markdown]
# | Discriminant | Roots |
# | :---: | :--- |
# | $\Delta$ = $b^2 - 4ac = 0$ | A single solution of $-b/(2a)$ |
# | $\Delta$ = $b^2 - 4ac > 0$ | Two distinct solutions |
# | $\Delta$ = $b^2 - 4ac < 0$ | No real solutions; both are complex. |

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# 1. What is a Git repository?

# %% [markdown]
# Ans: A Git repository is a centralised data storage location

# %% [markdown]
# 2. Git keeps track of BLANK in the files in our repository.

# %% [markdown]
# Ans: changes in the lines of codes

# %% [markdown]
# 3. What is a commit?

# %% [markdown]
# Ans: Commit is a way of saving changes made to the file

# %% [markdown]
# 4. What is a push?

# %% [markdown]
# Ans: A push is a way of uploading the commit or saved work to a repository

# %% [markdown]
# 5. What is a pull?

# %% [markdown]
# Ans: A pull downloads and syncs the latest changes found in the repository to merge and update the local copy of the same file

# %% [markdown]
# 6. What is the difference between GitHub and GitHub Desktop?

# %% [markdown]
# Ans: GitHub is accessed via the web and it is the site where GitHub repositories are hosted. On the other hand, GitHub Desktop is an application installed locally that the user can interact with to perform commit, push, and pull commands without the need of a command prompt or terminal.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# __Exercise 3 (A Matter of Statistics)__ The mean ($\mu$), standard deviation ($\sigma$), and Pearson correlation coefficient ($r$) are important statistical parameters. Given variables $x_{i}$ and $y_{i}$ representing the $i$-th values in a dataset with $n$ pairs, use Markdown notation to write the equations for these parameters.

# %% [markdown]
# Your equations should ideally look like the following. You might find [<u>this resource</u>](https://www.cmor-faculty.rice.edu/~heinken/latex/symbols.pdf) from Rice University useful.

# %% [markdown]
# $$
# \mu = \dfrac{1}{n}\sum_{i=1}^{n}x_{i}
# $$

# %% [markdown]
# $$
# \sigma = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (x_{i} - \mu)^2}

# %% [markdown]
# $$
# r = \dfrac{\sum_{i=1}^{n} (x_{i} - \mu_{X})(y_{i} - \mu_{y})}{\sqrt{\sum_{i=1}^{n} (x_{i} - \mu_{X})^2\sum_{i=1}^{n}(y_{i} - \mu_{Y})^2}}
