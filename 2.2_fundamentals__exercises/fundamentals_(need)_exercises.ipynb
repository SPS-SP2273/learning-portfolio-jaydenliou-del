# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# - creating variables using '='
# - checking if a variable is true or false using '=='
# - using the math package to do calculations
# - importing math and numpy packages

# %% [markdown]
# - creating variables using '='
# - checking if a variable is true or false using '=='
# - using the math package to do calculations
# - importing math and numpy packages
# - _functions ends with '()' parantheses_
# - _comments starts with '#'_
# - _using 'if' and 'else' statements to make decisions
# - _'[]' is used for lists of data_
# - _'{}' is used for dictionary_
# - _'()' is also used for math_
# - _when calling a function such as 'sqrt()', a '.' is used between the desired package and the function_

# %% [markdown]
# ## Exercise 2

# %%
import math
x, y = 3, 4
z = math.sqrt(x**2 + y**2)
print(x, y, z)
# Out:
# 3 4 5.0

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# | # | Term | Description |
# | :---: | :--- | :---: |
# | 1 | Function | performs a task, with some belonging to a specific package |
# | 2 | Arguments | the term the user inputs into the () of a function |
# | 3 | Comments | a form of annotation that begins with a # that explains the purpose of the code |
# | 4 | Indentations | define code blocks |
# | 5 | Packages | a library of features that a user can import |
# | 6 | . | indicates ownership and to call the function in a module or package |
# | 7 | : | indicates the start of an indented code block |
# | 8 | [ ] | used to store data as a list |
# | 9 | [ [], [] ] | creates a nested list, a list within a list |
# | 10 | {} | used to store data in a dictionary |

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# 5/2 performs a division with output as a float in 1 decimal place

# %%
5/2 # Division with output as a float
# Out:
# 2.5

# %%
8/2 # Division with output in 1 decimal place
# Out:
# 4.0

# %% [markdown]
# 5//2 performs a division but only round down a float

# %%
5//2 # Performs division but only rounds down a float
# Out:
# 2

# %%
6//2
# Out:
# 3

# %%
7//2
# Out:
# 3

# %% [markdown]
# 5%2 performs a division and ouputs a "1" if there is a remainder or decimal places, outputs a "0" if it is a whole number

# %%
5%2 # Expected answer is 2.5 but gets 1
# Out:
# 1

# %%
10%2 # Expected answer is 5 but gets 0
# Out:
# 0

# %%
3%2 # Odd/Even produces 1, 3/2 = 1.5
# Out:
# 1

# %%
4%2 # Even/Even produces 0, 4/2 = 2
# Out:
# 0

# %%
4%3 # Even/Odd produces 1
# Out:
# 1
