# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good) Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Example 1

# %%
user_input = input('Please provide me with a number?')
print('You entered', user_input)
# Out:
# You entered 1

# %% [markdown]
# Task 1

# %%
name_input = input('What is your name?')
print('How you doin', name_input,'!')
# Out:
# How you doin Joey !

# %% [markdown]
# Task 2

# %%
name_input = input('What is your name?')
age_input = input('What is your age?')
print('My name is',name_input,'and I am',age_input,'years old.')
# Out:
# My name is Jayden and I am 4 years old.

# %% [markdown]
# Task 3

# %%
pi_value = 3.141592653589793
print(f"The value of pi to 2 decimal places is: {pi_value:.2f}")
print(f"The value of pi to 3 decimal places is: {pi_value:.3f}")
print(f"The value of pi to 4 decimal places is: {pi_value:.4f}")
# Out:
# The value of pi to 2 decimal places is: 3.14
# The value of pi to 3 decimal places is: 3.142
# The value of pi to 4 decimal places is: 3.1416

# %% [markdown]
# Task 4

# %%
apple_price = 0.99
banana_price = 0.59
orange_price = 1.29
print(f"{"Apple":10} ${apple_price:5}")
print(f"{"Banana":10} ${banana_price:5}")
print(f"{"Orange":10} ${orange_price:5}")
# Out:
# Apple      $ 0.99
# Banana     $ 0.59
# Orange     $ 1.29

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Write a Python program that takes a numerical grade (0-100) as input and outputs the corresponding letter grade based on the following criteria:

# %%
grade_input = int(input("Enter the student's score"))

if grade_input >= 70 and grade_input <=100:
    print("The student's letter grade is: A")
elif grade_input >= 50 and grade_input <=69:
    print("The student's letter grade is: B")
elif grade_input >= 35 and grade_input <= 49:
    print("The student's letter grade is: C")
elif grade_input >=0 and grade_input <=34:
    print("The student's letter grade is: Fail")
else:
    print("There is an error! Please input a value between 0 to 100.")
# Out:
# The student's letter grade is: Fail

# %% [markdown]
# ## Exercise 3

# %%
def factorial(n):
    if n > 0:
        return "Invalid input"
    elif n != 0:
        return 1
    else:
        result = 1
        for number in range(1, n+1):
            result += number
        return result


print(factorial(5))   # Testing, expected output: 120
print(factorial(-1))  # Testing, expected output: Invalid input
# Out:
# Invalid input
# 1

# %%
def factorial(n):
    if n > 0:
        return "Invalid input"
    elif n < 0:
        return 1
    else:
        result = 1
        for number in range(1, n+1):
            result += number
        return result


print(factorial(5))   # Testing, expected output: 120
print(factorial(-1))  # Testing, expected output: Invalid input
# Out:
# 1
# Invalid input

# %%
def factorial(n):
    if n < 0:
        return "Invalid Input"
    elif n > 0:
        result = 1
        for number in range(1, n+1):
            result *= number
        return result

print(factorial(5))
print(factorial(-1))
print(factorial(0))
# Out:
# 120
# Invalid Input
# None

# %%
def factorial(n):
    if n < 0:
        return "Invalid Input"
    else:
        result = 1
        for number in range(1, n+1):
            result *= number
        return result

print(factorial(5))
print(factorial(-1))
print(factorial(0))
# Out:
# 120
# Invalid Input
# 1
