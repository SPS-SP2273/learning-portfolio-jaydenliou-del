# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Some nomenclature

# %% [markdown]
# # 2 Comparing the two ‘dialects’

# %%
import numpy as np

x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %% [markdown]
# ### pyplot Interface

# %%
import matplotlib.pyplot as plt

plt.plot(x, cos_x, label = 'cos(x)')
plt.plot(x, sin_x, label = 'sin(x)')
plt.legend()

# %% [markdown]
# ### OO Interface

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
# 'fig' or figure is the "canvas for your painting"
# 'ax' or axes is "area of your canvas"
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()

# %% [markdown]
# # 3 What is OO ax, really?

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1)

ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')

ax[0].legend()
ax[1].legend()

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)

# %%
type(ax) # ax is a NumPy array
# Out:
# numpy.ndarray

# %%
ax.shape
# Out:
# (2,)

# %%
type(ax[0])
# Out:
# matplotlib.axes._axes.Axes

# %% [markdown]
# # 4 A complete OO example

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(5, 5), sharex=True)

ax[0].plot(x, cos_x, label = r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label = r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation = 0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$') # adding a super title to the figure (not plot)

fig.tight_layout()

# %% [markdown]
# # 5 Multiple rows and columns

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(5,5), sharex='col', sharey='col')

top_left, top_right, bottom_left, bottom_right = ax.flatten()

top_left.set_title('Top Left')
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=4)
bottom_right.hlines(y=4, xmin=0, xmax=5)

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()

# %% [markdown]
# ### Using ax

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(5,5), sharex='col', sharey='row')

# %%
ax.shape
# Out:
# (2, 2)

# %%
ax[0, 0].set_title('Top Left')
ax[0, 1].set_title('Top Right')
ax[1, 0].set_title('Bottom Left')
ax[1, 1].set_title('Bottom Right')

# ax[0, 0] means first row, first column
# ax[0, 1] means first row, second column
# Out:
# Text(0.5, 1.0, 'Bottom Right')

# %%
top_left, top_right, bottom_left, bottom_right = ax.flatten()

#top_left gets ax[0, 0]
#top_right gets ax[0, 1]
#bottom_left gets ax[1, 0]
#bottom_right gets ax[1, 1]

# %%
top_left.hlines(y=1, xmin=0, xmax=5)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=5)
bottom_right.hlines(y=4, xmin=0, xmax=5)

#y: The vertical position where the line sits.
#xmin: Where the line starts on the horizontal axis.
#xmax: Where the line ends on the horizontal axis.

# %% [markdown]
# ## 5.1 Sharing axes

# %% [markdown]
# ## 5.2 Accessing all axes

# %% [markdown]
# # 6 Other useful plots

# %% [markdown]
# ## 6.1 Histograms

# %% [markdown]
# ### Data

# %%
# Your code here

# %% [markdown]
# ### A quick helper function

# %%
# Your code here

# %% [markdown]
# ### The histogram

# %%
# Your code here

# %% [markdown]
# ## 6.2 Scatter plots

# %% [markdown]
# ## 6.3 Bar charts

# %% [markdown]
# ## 6.4 Pie charts

# %% [markdown]
# ## Other Notes

# %%
# Using ax and fig 

import matplotlib.pyplot as plt

x = [0, 1, 2]
y = [0, 1, 4]
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(x, y, 'b-')
ax2.plot(x, y, 'g--')
plt.show()
